# %% [markdown]
# #casting
# 1- integer to float

# %%
num_value = 32
number = float(num_value)
print(type(number))
# Out:
# <class 'float'>

# %%
numb_value= 32.5
number = int(numb_value)
print(type(number))
print(number)
# Out:
# <class 'int'>
# 32

# %%
value = "45"
integer_value = int(value)
float_value = float(value)
print(type(integer_value))
print(type(float_value))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# #Dnamic type casting
# #1- Explicit type casting

# %%
num_string = "100"
num_integer = int(num_string)
print(type(num_integer))
# Out:
# <class 'int'>

# %%
print("this is my book")
# Out:
# this is my book

# %%
print("test")
# Out:
# test

# %% [markdown]
# #dynamic type casting

# %%
user_input = "6.0"  # manually assign a number

if '.' in user_input:
    converted_value = float(user_input)
else:
    converted_value = int(user_input)

print(type(converted_value))
# Out:
# <class 'float'>
